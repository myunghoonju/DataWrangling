# %% [markdown]
# <h3>Basic python

# %%
import numpy as np

# %%
data = {
    i:np.random.rand()
    for i in range(7)
        }

# %%
data
# Out:
# {0: 0.8254684260579072,
#  1: 0.37968279400495686,
#  2: 0.8066730652631922,
#  3: 0.05501517762759933,
#  4: 0.5635190066476952,
#  5: 0.9804392215046032,
#  6: 0.9245269820952022}

# %%
def add_numbers(a,b):
  """
  Add two numbers together
  Returns
  ---
  the_sum : type of args
  """
  return a + b

# %%
add_numbers?

# %% [markdown]
# Can see source code if possible

# %%
add_numbers??

# %%
# %pwd  #dir()
# Out:
# '/content'

# %%
# %hist #print command input history

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(50).cumsum())

# %%
# Out:
#   File "<ipython-input-24-58cae8d7db7a>", line 1
#     <p>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# assigning a variable in py equals a <mark>reference</mark> to the obj on the right
# <br>
#     var a,b -> a list contains [1,2,3]

# %%
a = [1,2,3]

# %%
b = a

# %%
a.append(4)

# %%
print(b)
# Out:
# [1, 2, 3, 4]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import some_module as sm

# %%
z = sm.f(5)
print(z)
print(sm.pi)
# Out:
# 7
# 3.141592

# %%
z is list
# Out:
# False

# %%
z is not list
# Out:
# True

# %%
a_tuple = (3,5,(4,5))

# %%
type(a_tuple)
# Out:
# tuple

# %%
a = 'today is a new day'

# %%
b = a.replace('new','old')

# %%
b
# Out:
# 'today is a old day'

# %%
list(b)
# Out:
# ['t',
#  'o',
#  'd',
#  'a',
#  'y',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'o',
#  'l',
#  'd',
#  ' ',
#  'd',
#  'a',
#  'y']

# %%
b[:4] #slicing
# Out:
# 'toda'

# %%
a = r'this\has\no\special\characters' #r stands for raw

# %%
a
# Out:
# 'this\\has\\no\\special\\characters'

# %%
b = r'한국어도\될까?'

# %%
b
# Out:
# '한국어도\\될까?'

# %%
#Bytes & Unicode
val = "espanol"
print(val)
val_utf8 = val.encode('utf-8')
type(val_utf8)
# Out:
# espanol
# bytes

# %%
val_utf8
# Out:
# b'espanol'

# %%
decoded_val = val_utf8.decode('utf-8')
print(decoded_val)
# Out:
# espanol

# %%
val.encode('latin1')
# Out:
# b'espanol'

# %%
val.encode('utf-16')
# Out:
# b'\xff\xfee\x00s\x00p\x00a\x00n\x00o\x00l\x00'

# %%
decoded_val.encode('utf-16le')
# Out:
# b'e\x00s\x00p\x00a\x00n\x00o\x00l\x00'

# %%
bytes_val = b'this is bytes'

# %%
decoded = bytes_val.decode('utf8')

# %%
decoded
# Out:
# 'this is bytes'

# %%
#None 45p
